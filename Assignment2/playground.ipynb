# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# ## Loading Excel file

# %%
normal_file = pd.read_excel('dataset/SWaT_Dataset_Normal_v0.xlsx', header=1, index_col=None)

# %%
normal_file.head()
# Out:
#                 Timestamp    FIT101    LIT101  MV101  P101  P102    AIT201  \
# 0   22/12/2015 4:00:00 PM  2.470294  261.5804      2     2     1  244.3284
# 1   22/12/2015 4:00:01 PM  2.457163  261.1879      2     2     1  244.3284
# 2   22/12/2015 4:00:02 PM  2.439548  260.9131      2     2     1  244.3284
# 3   22/12/2015 4:00:03 PM  2.428338  260.2850      2     2     1  244.3284
# 4   22/12/2015 4:00:04 PM  2.424815  259.8925      2     2     1  244.4245
#
#     AIT202   AIT203    FIT201      ...        P501  P502    PIT501  PIT502  \
# 0  8.19008  306.101  2.471278      ...           1     1  10.02948     0.0
# 1  8.19008  306.101  2.468587      ...           1     1  10.02948     0.0
# 2  8.19008  306.101  2.467305      ...           1     1  10.02948     0.0
# 3  8.19008  306.101  2.466536      ...           1     1  10.02948     0.0
# 4  8.19008  306.101  2.466536      ...           1     1  10.02948     0.0
#
#      PIT503    FIT601  P601  P602  P603  Normal/Attack
# ...

# %%
normal_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496800 entries, 0 to 496799
# Data columns (total 53 columns):
#  Timestamp       496800 non-null object
# FIT101           496800 non-null float64
# LIT101           496800 non-null float64
# MV101            496800 non-null int64
# P101             496800 non-null int64
# P102             496800 non-null int64
# AIT201           496800 non-null float64
# AIT202           496800 non-null float64
# AIT203           496800 non-null float64
# FIT201           496800 non-null float64
# MV201            496800 non-null int64
# P201             496800 non-null int64
# P202             496800 non-null int64
# P203             496800 non-null int64
# P204             496800 non-null int64
# P205             496800 non-null int64
# P206             496800 non-null int64
# DPIT301          496800 non-null float64
# FIT301           496800 non-null float64
# LIT301           496800 non-null float64
# MV301            496800 non-null int64
# ...

# %%
normal_file.rename(columns={' Timestamp':'Timestamp'}, inplace=True)

# %%
normal_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496800 entries, 0 to 496799
# Data columns (total 53 columns):
# Timestamp        496800 non-null object
# FIT101           496800 non-null float64
# LIT101           496800 non-null float64
# MV101            496800 non-null int64
# P101             496800 non-null int64
# P102             496800 non-null int64
# AIT201           496800 non-null float64
# AIT202           496800 non-null float64
# AIT203           496800 non-null float64
# FIT201           496800 non-null float64
# MV201            496800 non-null int64
# P201             496800 non-null int64
# P202             496800 non-null int64
# P203             496800 non-null int64
# P204             496800 non-null int64
# P205             496800 non-null int64
# P206             496800 non-null int64
# DPIT301          496800 non-null float64
# FIT301           496800 non-null float64
# LIT301           496800 non-null float64
# MV301            496800 non-null int64
# ...

# %% [markdown]
# ## Saving Excel DataFrame to CSV format
#
# read_excel is not optimized in Python and is much slower to read/load/write in Excel format. Hence, converting it to .csv format

# %%
normal_file.to_csv("dataset/Sensor_data_Normal.csv", index=None)

# %%
normal_csv = pd.read_csv("dataset/Sensor_data_Normal.csv", parse_dates=True, index_col='Timestamp')

# %%
normal_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 496800 entries, 2015-12-22 16:00:00 to 2015-12-28 09:59:59
# Data columns (total 52 columns):
# FIT101           496800 non-null float64
# LIT101           496800 non-null float64
# MV101            496800 non-null int64
# P101             496800 non-null int64
# P102             496800 non-null int64
# AIT201           496800 non-null float64
# AIT202           496800 non-null float64
# AIT203           496800 non-null float64
# FIT201           496800 non-null float64
# MV201            496800 non-null int64
# P201             496800 non-null int64
# P202             496800 non-null int64
# P203             496800 non-null int64
# P204             496800 non-null int64
# P205             496800 non-null int64
# P206             496800 non-null int64
# DPIT301          496800 non-null float64
# FIT301           496800 non-null float64
# LIT301           496800 non-null float64
# MV301            496800 non-null int64
# ...

# %%
normal_csv.index
# Out:
# DatetimeIndex(['2015-12-22 16:00:00', '2015-12-22 16:00:01',
#                '2015-12-22 16:00:02', '2015-12-22 16:00:03',
#                '2015-12-22 16:00:04', '2015-12-22 16:00:05',
#                '2015-12-22 16:00:06', '2015-12-22 16:00:07',
#                '2015-12-22 16:00:08', '2015-12-22 16:00:09',
#                ...
#                '2015-12-28 09:59:50', '2015-12-28 09:59:51',
#                '2015-12-28 09:59:52', '2015-12-28 09:59:53',
#                '2015-12-28 09:59:54', '2015-12-28 09:59:55',
#                '2015-12-28 09:59:56', '2015-12-28 09:59:57',
#                '2015-12-28 09:59:58', '2015-12-28 09:59:59'],
#               dtype='datetime64[ns]', name=u'Timestamp', length=496800, freq=None)

# %%
normal_csv.head()
# Out:
#                        FIT101    LIT101  MV101  P101  P102    AIT201   AIT202  \
# Timestamp
# 2015-12-22 16:00:00  2.470294  261.5804      2     2     1  244.3284  8.19008
# 2015-12-22 16:00:01  2.457163  261.1879      2     2     1  244.3284  8.19008
# 2015-12-22 16:00:02  2.439548  260.9131      2     2     1  244.3284  8.19008
# 2015-12-22 16:00:03  2.428338  260.2850      2     2     1  244.3284  8.19008
# 2015-12-22 16:00:04  2.424815  259.8925      2     2     1  244.4245  8.19008
#
#                       AIT203    FIT201  MV201      ...        P501  P502  \
# Timestamp                                          ...
# 2015-12-22 16:00:00  306.101  2.471278      2      ...           1     1
# 2015-12-22 16:00:01  306.101  2.468587      2      ...           1     1
# 2015-12-22 16:00:02  306.101  2.467305      2      ...           1     1
# 2015-12-22 16:00:03  306.101  2.466536      2      ...           1     1
# ...

# %%
normal_csv['FIT101'].plot(figsize=(15,5))

# %% [markdown]
# ### Daily Trend

# %%
df1 = normal_csv.groupby(pd.TimeGrouper('D'))

# %%
df1['LIT101'].plot(figsize=(15,5))
# Out:
# Timestamp
# 2015-12-22    Axes(0.125,0.125;0.775x0.775)
# 2015-12-23    Axes(0.125,0.125;0.775x0.775)
# 2015-12-24    Axes(0.125,0.125;0.775x0.775)
# 2015-12-25    Axes(0.125,0.125;0.775x0.775)
# 2015-12-26    Axes(0.125,0.125;0.775x0.775)
# 2015-12-27    Axes(0.125,0.125;0.775x0.775)
# 2015-12-28    Axes(0.125,0.125;0.775x0.775)
# Freq: D, Name: LIT101, dtype: object

# %% [markdown]
# ### Hourly Trend

# %%
one_day_data = df1.get_group('2015-12-22')

# %%
one_day_data[0:10]
# Out:
#                        FIT101    LIT101  MV101  P101  P102    AIT201   AIT202  \
# Timestamp
# 2015-12-22 16:00:00  2.470294  261.5804      2     2     1  244.3284  8.19008
# 2015-12-22 16:00:01  2.457163  261.1879      2     2     1  244.3284  8.19008
# 2015-12-22 16:00:02  2.439548  260.9131      2     2     1  244.3284  8.19008
# 2015-12-22 16:00:03  2.428338  260.2850      2     2     1  244.3284  8.19008
# 2015-12-22 16:00:04  2.424815  259.8925      2     2     1  244.4245  8.19008
# 2015-12-22 16:00:05  2.425456  260.0495      2     2     1  244.5847  8.19008
# 2015-12-22 16:00:06  2.472857  260.2065      2     2     1  244.5847  8.19008
# 2015-12-22 16:00:07  2.513532  260.5991      2     2     1  244.5847  8.19008
# 2015-12-22 16:00:08  2.559972  261.0309      2     2     1  244.5847  8.19008
# 2015-12-22 16:00:09  2.598085  261.1093      2     2     1  244.8090  8.19008
#
#                       AIT203    FIT201  MV201      ...        P501  P502  \
# ...

# %%
hourly = one_day_data.groupby(pd.TimeGrouper('H'))

# %%
hourly.count()
# Out:
#                      FIT101  LIT101  MV101  P101  P102  AIT201  AIT202  \
# Timestamp
# 2015-12-22 16:00:00    3600    3600   3600  3600  3600    3600    3600
# 2015-12-22 17:00:00    3600    3600   3600  3600  3600    3600    3600
# 2015-12-22 18:00:00    3600    3600   3600  3600  3600    3600    3600
# 2015-12-22 19:00:00    3600    3600   3600  3600  3600    3600    3600
# 2015-12-22 20:00:00    3600    3600   3600  3600  3600    3600    3600
# 2015-12-22 21:00:00    3600    3600   3600  3600  3600    3600    3600
# 2015-12-22 22:00:00    3600    3600   3600  3600  3600    3600    3600
# 2015-12-22 23:00:00    3600    3600   3600  3600  3600    3600    3600
#
#                      AIT203  FIT201  MV201      ...        P501  P502  PIT501  \
# Timestamp                                       ...
# 2015-12-22 16:00:00    3600    3600   3600      ...        3600  3600    3600
# 2015-12-22 17:00:00    3600    3600   3600      ...        3600  3600    3600
# ...

# %%
plt.figure();
one_day_data.LIT101.plot(figsize=(15,5))
